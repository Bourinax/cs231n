# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.340467
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.537372 analytic: 0.537372, relative error: 1.242245e-07
# numerical: 0.788889 analytic: 0.788889, relative error: 3.260464e-08
# numerical: -0.679967 analytic: -0.679967, relative error: 7.885272e-08
# numerical: 1.956207 analytic: 1.956207, relative error: 9.494767e-09
# numerical: 0.939709 analytic: 0.939709, relative error: 1.451148e-08
# numerical: -1.145629 analytic: -1.145629, relative error: 7.055179e-09
# numerical: -0.886366 analytic: -0.886366, relative error: 6.020643e-08
# numerical: -0.880242 analytic: -0.880242, relative error: 3.406604e-09
# numerical: 1.457839 analytic: 1.457839, relative error: 1.598939e-08
# numerical: 0.577635 analytic: 0.577634, relative error: 1.296349e-07
# numerical: -1.088799 analytic: -1.088799, relative error: 5.191507e-08
# numerical: -2.428798 analytic: -2.428798, relative error: 3.083650e-10
# numerical: 2.554711 analytic: 2.554711, relative error: 1.638672e-08
# numerical: -0.282859 analytic: -0.282859, relative error: 1.451995e-07
# numerical: 1.200467 analytic: 1.200467, relative error: 2.053838e-08
# numerical: -3.125410 analytic: -3.125410, relative error: 1.247300e-08
# numerical: -2.276653 analytic: -2.276653, relative error: 2.060676e-08
# numerical: -0.846828 analytic: -0.846828, relative error: 1.315407e-08
# numerical: 0.338932 analytic: 0.338932, relative error: 1.489680e-07
# numerical: 1.839883 analytic: 1.839883, relative error: 1.813664e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.340467e+00 computed in 0.225923s
# vectorized loss: 2.340467e+00 computed in 0.003552s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
steps = 6
learning_rate_vect = np.geomspace(learning_rates[0], learning_rates[1], steps, endpoint = True)
regularization_strength_vect = np.geomspace(regularization_strengths[0],\
                                            regularization_strengths[1], steps, endpoint = True)
print(learning_rate_vect)
for i in range(steps): 
   for u in range(steps):
      softmax = Softmax()
      loss_hist = softmax.train(X_train, y_train, learning_rate=learning_rate_vect[i],\
                         reg=regularization_strength_vect[u], num_iters=800, verbose=True)

   #X_train
   #X_val
   #X_test

      y_train_pred = softmax.predict(X_train)
      train_accur = np.mean(y_train == y_train_pred)
      #print('training accuracy: %f' % (train_accur, ))
      y_val_pred = softmax.predict(X_val)
      val_accur = np.mean(y_val == y_val_pred)
      #print('validation accuracy: %f' % (val_accur, ))
      results[learning_rate_vect[i],regularization_strength_vect[u]] = [train_accur, val_accur]

      if(val_accur > best_val):
         best_val=val_accur
         best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# [1.00000000e-07 1.37972966e-07 1.90365394e-07 2.62652780e-07
#  3.62389832e-07 5.00000000e-07]
# iteration 0 / 800: loss 781.516783
# iteration 100 / 800: loss 286.872723
# iteration 200 / 800: loss 106.289778
# iteration 300 / 800: loss 40.202040
# iteration 400 / 800: loss 16.039283
# iteration 500 / 800: loss 7.209940
# iteration 600 / 800: loss 3.918032
# iteration 700 / 800: loss 2.727078
# iteration 0 / 800: loss 884.661935
# iteration 100 / 800: loss 279.469492
# iteration 200 / 800: loss 89.519023
# iteration 300 / 800: loss 29.686867
# iteration 400 / 800: loss 10.843813
# iteration 500 / 800: loss 4.835239
# iteration 600 / 800: loss 2.907515
# iteration 700 / 800: loss 2.338881
# iteration 0 / 800: loss 1009.695777
# iteration 100 / 800: loss 268.894234
# iteration 200 / 800: loss 72.899875
# iteration 300 / 800: loss 20.833503
# iteration 400 / 800: loss 7.121831
# iteration 500 / 800: loss 3.385965
# iteration 600 / 800: loss 2.523347
# iteration 700 / 800: loss 2.198798
# iteration 0 / 800: loss 1166.356665
# iteration 100 / 800: loss 255.620765
# iteration 200 / 800: loss 57.312173
# iteration 300 / 800: loss 14.104790
# iteration 400 / 800: loss 4.794866
# iteration 500 / 800: loss 2.739120
# iteration 600 / 800: loss 2.251647
# iteration 700 / 800: loss 2.172664
# iteration 0 / 800: loss 1356.236881
# iteration 100 / 800: loss 236.903670
# iteration 200 / 800: loss 42.802835
# iteration 300 / 800: loss 9.155132
# iteration 400 / 800: loss 3.354475
# iteration 500 / 800: loss 2.352858
# iteration 600 / 800: loss 2.130108
# iteration 700 / 800: loss 2.144872
# iteration 0 / 800: loss 1568.433439
# iteration 100 / 800: loss 211.129870
# iteration 200 / 800: loss 30.027357
# iteration 300 / 800: loss 5.886643
# iteration 400 / 800: loss 2.620635
# iteration 500 / 800: loss 2.180801
# iteration 600 / 800: loss 2.227910
# iteration 700 / 800: loss 2.152131
# iteration 0 / 800: loss 776.502083
# iteration 100 / 800: loss 194.862508
# iteration 200 / 800: loss 50.237388
# iteration 300 / 800: loss 14.116412
# iteration 400 / 800: loss 5.043066
# iteration 500 / 800: loss 2.850766
# iteration 600 / 800: loss 2.242402
# iteration 700 / 800: loss 2.151187
# iteration 0 / 800: loss 890.752423
# iteration 100 / 800: loss 182.245890
# iteration 200 / 800: loss 38.661971
# iteration 300 / 800: loss 9.499733
# iteration 400 / 800: loss 3.586537
# iteration 500 / 800: loss 2.337181
# iteration 600 / 800: loss 2.181613
# iteration 700 / 800: loss 2.107792
# iteration 0 / 800: loss 1008.119958
# iteration 100 / 800: loss 162.655420
# iteration 200 / 800: loss 27.799586
# iteration 300 / 800: loss 6.227430
# iteration 400 / 800: loss 2.730137
# iteration 500 / 800: loss 2.226031
# iteration 600 / 800: loss 2.180775
# iteration 700 / 800: loss 2.138530
# iteration 0 / 800: loss 1167.632356
# iteration 100 / 800: loss 143.907912
# iteration 200 / 800: loss 19.338581
# iteration 300 / 800: loss 4.237333
# iteration 400 / 800: loss 2.384824
# iteration 500 / 800: loss 2.174975
# iteration 600 / 800: loss 2.091611
# iteration 700 / 800: loss 2.184329
# iteration 0 / 800: loss 1340.366282
# iteration 100 / 800: loss 120.861188
# iteration 200 / 800: loss 12.721372
# iteration 300 / 800: loss 3.034157
# iteration 400 / 800: loss 2.190998
# iteration 500 / 800: loss 2.133335
# iteration 600 / 800: loss 2.104009
# iteration 700 / 800: loss 2.159904
# iteration 0 / 800: loss 1530.254441
# iteration 100 / 800: loss 96.544467
# iteration 200 / 800: loss 7.964685
# iteration 300 / 800: loss 2.519540
# iteration 400 / 800: loss 2.155587
# iteration 500 / 800: loss 2.172578
# iteration 600 / 800: loss 2.089018
# iteration 700 / 800: loss 2.123035
# iteration 0 / 800: loss 769.829693
# iteration 100 / 800: loss 114.764882
# iteration 200 / 800: loss 18.655231
# iteration 300 / 800: loss 4.563924
# iteration 400 / 800: loss 2.439275
# iteration 500 / 800: loss 2.170923
# iteration 600 / 800: loss 2.145934
# iteration 700 / 800: loss 2.050297
# iteration 0 / 800: loss 889.555053
# iteration 100 / 800: loss 99.859807
# iteration 200 / 800: loss 12.971413
# iteration 300 / 800: loss 3.313252
# iteration 400 / 800: loss 2.262543
# iteration 500 / 800: loss 2.051735
# iteration 600 / 800: loss 2.080843
# iteration 700 / 800: loss 2.131511
# iteration 0 / 800: loss 1029.569650
# iteration 100 / 800: loss 83.593695
# iteration 200 / 800: loss 8.623337
# iteration 300 / 800: loss 2.634386
# iteration 400 / 800: loss 2.177247
# iteration 500 / 800: loss 2.189588
# iteration 600 / 800: loss 2.134857
# iteration 700 / 800: loss 2.079650
# iteration 0 / 800: loss 1165.424830
# iteration 100 / 800: loss 65.291645
# iteration 200 / 800: loss 5.541784
# iteration 300 / 800: loss 2.355783
# iteration 400 / 800: loss 2.118162
# iteration 500 / 800: loss 2.182126
# iteration 600 / 800: loss 2.149569
# iteration 700 / 800: loss 2.147890
# iteration 0 / 800: loss 1335.191109
# iteration 100 / 800: loss 49.007850
# iteration 200 / 800: loss 3.791570
# iteration 300 / 800: loss 2.205256
# iteration 400 / 800: loss 2.112460
# iteration 500 / 800: loss 2.099643
# iteration 600 / 800: loss 2.177514
# iteration 700 / 800: loss 2.120390
# iteration 0 / 800: loss 1531.364517
# iteration 100 / 800: loss 34.640832
# iteration 200 / 800: loss 2.869283
# iteration 300 / 800: loss 2.178533
# iteration 400 / 800: loss 2.129392
# iteration 500 / 800: loss 2.128630
# iteration 600 / 800: loss 2.133204
# iteration 700 / 800: loss 2.092740
# iteration 0 / 800: loss 771.033495
# iteration 100 / 800: loss 56.264574
# iteration 200 / 800: loss 5.930923
# iteration 300 / 800: loss 2.344279
# iteration 400 / 800: loss 2.131252
# iteration 500 / 800: loss 2.097832
# iteration 600 / 800: loss 2.104859
# iteration 700 / 800: loss 2.085773
# iteration 0 / 800: loss 896.584273
# iteration 100 / 800: loss 44.590147
# iteration 200 / 800: loss 4.089596
# iteration 300 / 800: loss 2.241079
# iteration 400 / 800: loss 2.087397
# iteration 500 / 800: loss 2.026049
# iteration 600 / 800: loss 2.097531
# iteration 700 / 800: loss 2.114615
# iteration 0 / 800: loss 1028.345615
# iteration 100 / 800: loss 32.946168
# iteration 200 / 800: loss 3.102394
# iteration 300 / 800: loss 2.140626
# iteration 400 / 800: loss 2.103990
# iteration 500 / 800: loss 2.059607
# iteration 600 / 800: loss 2.111763
# iteration 700 / 800: loss 2.111914
# iteration 0 / 800: loss 1156.649004
# iteration 100 / 800: loss 22.707860
# iteration 200 / 800: loss 2.489242
# iteration 300 / 800: loss 2.112517
# iteration 400 / 800: loss 2.100414
# iteration 500 / 800: loss 2.131223
# iteration 600 / 800: loss 2.128472
# iteration 700 / 800: loss 2.104972
# iteration 0 / 800: loss 1357.553298
# iteration 100 / 800: loss 15.311952
# iteration 200 / 800: loss 2.284241
# iteration 300 / 800: loss 2.097737
# iteration 400 / 800: loss 2.096618
# iteration 500 / 800: loss 2.146279
# iteration 600 / 800: loss 2.169300
# iteration 700 / 800: loss 2.161245
# iteration 0 / 800: loss 1535.109844
# iteration 100 / 800: loss 9.557992
# iteration 200 / 800: loss 2.137457
# iteration 300 / 800: loss 2.114446
# iteration 400 / 800: loss 2.133250
# iteration 500 / 800: loss 2.122917
# iteration 600 / 800: loss 2.110340
# iteration 700 / 800: loss 2.180498
# iteration 0 / 800: loss 781.176788
# iteration 100 / 800: loss 21.983330
# iteration 200 / 800: loss 2.626031
# iteration 300 / 800: loss 2.112817
# iteration 400 / 800: loss 2.036757
# iteration 500 / 800: loss 2.061631
# iteration 600 / 800: loss 2.029548
# iteration 700 / 800: loss 2.063395
# iteration 0 / 800: loss 888.512592
# iteration 100 / 800: loss 15.145813
# iteration 200 / 800: loss 2.341587
# iteration 300 / 800: loss 2.089188
# iteration 400 / 800: loss 2.122376
# iteration 500 / 800: loss 2.114904
# iteration 600 / 800: loss 2.088436
# iteration 700 / 800: loss 2.083582
# iteration 0 / 800: loss 1006.327153
# iteration 100 / 800: loss 9.950655
# iteration 200 / 800: loss 2.171486
# iteration 300 / 800: loss 2.131793
# iteration 400 / 800: loss 2.101904
# iteration 500 / 800: loss 2.087688
# iteration 600 / 800: loss 2.129160
# iteration 700 / 800: loss 2.122448
# iteration 0 / 800: loss 1174.221461
# iteration 100 / 800: loss 6.551130
# iteration 200 / 800: loss 2.148286
# iteration 300 / 800: loss 2.119674
# iteration 400 / 800: loss 2.112719
# iteration 500 / 800: loss 2.090011
# iteration 600 / 800: loss 2.160938
# iteration 700 / 800: loss 2.121418
# iteration 0 / 800: loss 1326.337026
# iteration 100 / 800: loss 4.357323
# iteration 200 / 800: loss 2.165458
# iteration 300 / 800: loss 2.156470
# iteration 400 / 800: loss 2.165502
# iteration 500 / 800: loss 2.116846
# iteration 600 / 800: loss 2.141820
# iteration 700 / 800: loss 2.162248
# iteration 0 / 800: loss 1546.756182
# iteration 100 / 800: loss 3.105411
# iteration 200 / 800: loss 2.160257
# iteration 300 / 800: loss 2.172658
# iteration 400 / 800: loss 2.119831
# iteration 500 / 800: loss 2.147818
# iteration 600 / 800: loss 2.197696
# iteration 700 / 800: loss 2.142815
# iteration 0 / 800: loss 781.818361
# iteration 100 / 800: loss 6.932451
# iteration 200 / 800: loss 2.051774
# iteration 300 / 800: loss 2.084074
# iteration 400 / 800: loss 2.070039
# iteration 500 / 800: loss 2.060153
# iteration 600 / 800: loss 2.100652
# iteration 700 / 800: loss 2.088110
# iteration 0 / 800: loss 885.858186
# iteration 100 / 800: loss 4.653249
# iteration 200 / 800: loss 2.122466
# iteration 300 / 800: loss 2.138002
# iteration 400 / 800: loss 2.162784
# iteration 500 / 800: loss 2.084757
# iteration 600 / 800: loss 2.100456
# iteration 700 / 800: loss 2.057110
# iteration 0 / 800: loss 1008.468261
# iteration 100 / 800: loss 3.431473
# iteration 200 / 800: loss 2.121142
# iteration 300 / 800: loss 2.118236
# iteration 400 / 800: loss 2.146830
# iteration 500 / 800: loss 2.038849
# iteration 600 / 800: loss 2.096002
# iteration 700 / 800: loss 2.121562
# iteration 0 / 800: loss 1177.549230
# iteration 100 / 800: loss 2.679014
# iteration 200 / 800: loss 2.156848
# iteration 300 / 800: loss 2.110840
# iteration 400 / 800: loss 2.043275
# iteration 500 / 800: loss 2.091340
# iteration 600 / 800: loss 2.105804
# iteration 700 / 800: loss 2.092425
# iteration 0 / 800: loss 1317.316888
# iteration 100 / 800: loss 2.316287
# iteration 200 / 800: loss 2.137494
# iteration 300 / 800: loss 2.150195
# iteration 400 / 800: loss 2.129411
# iteration 500 / 800: loss 2.102124
# iteration 600 / 800: loss 2.088154
# iteration 700 / 800: loss 2.163584
# iteration 0 / 800: loss 1545.522063
# iteration 100 / 800: loss 2.187455
# iteration 200 / 800: loss 2.135736
# iteration 300 / 800: loss 2.192827
# iteration 400 / 800: loss 2.141685
# iteration 500 / 800: loss 2.133393
# iteration 600 / 800: loss 2.159050
# iteration 700 / 800: loss 2.159923
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.329653 val accuracy: 0.342000
# lr 1.000000e-07 reg 2.871746e+04 train accuracy: 0.320429 val accuracy: 0.341000
# lr 1.000000e-07 reg 3.298770e+04 train accuracy: 0.316082 val accuracy: 0.330000
# lr 1.000000e-07 reg 3.789291e+04 train accuracy: 0.316020 val accuracy: 0.332000
# lr 1.000000e-07 reg 4.352753e+04 train accuracy: 0.313531 val accuracy: 0.328000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.304918 val accuracy: 0.323000
# lr 1.379730e-07 reg 2.500000e+04 train accuracy: 0.330592 val accuracy: 0.338000
# lr 1.379730e-07 reg 2.871746e+04 train accuracy: 0.321776 val accuracy: 0.340000
# lr 1.379730e-07 reg 3.298770e+04 train accuracy: 0.327571 val accuracy: 0.345000
# lr 1.379730e-07 reg 3.789291e+04 train accuracy: 0.315469 val accuracy: 0.331000
# lr 1.379730e-07 reg 4.352753e+04 train accuracy: 0.303959 val accuracy: 0.321000
# lr 1.379730e-07 reg 5.000000e+04 train accuracy: 0.305143 val accuracy: 0.323000
# lr 1.903654e-07 reg 2.500000e+04 train accuracy: 0.332918 val accuracy: 0.334000
# lr 1.903654e-07 reg 2.871746e+04 train accuracy: 0.324469 val accuracy: 0.333000
# lr 1.903654e-07 reg 3.298770e+04 train accuracy: 0.318061 val accuracy: 0.333000
# lr 1.903654e-07 reg 3.789291e+04 train accuracy: 0.315980 val accuracy: 0.331000
# lr 1.903654e-07 reg 4.352753e+04 train accuracy: 0.305959 val accuracy: 0.322000
# lr 1.903654e-07 reg 5.000000e+04 train accuracy: 0.304735 val accuracy: 0.313000
# lr 2.626528e-07 reg 2.500000e+04 train accuracy: 0.326122 val accuracy: 0.345000
# lr 2.626528e-07 reg 2.871746e+04 train accuracy: 0.325265 val accuracy: 0.337000
# lr 2.626528e-07 reg 3.298770e+04 train accuracy: 0.320776 val accuracy: 0.336000
# lr 2.626528e-07 reg 3.789291e+04 train accuracy: 0.312551 val accuracy: 0.333000
# lr 2.626528e-07 reg 4.352753e+04 train accuracy: 0.316939 val accuracy: 0.325000
# lr 2.626528e-07 reg 5.000000e+04 train accuracy: 0.300633 val accuracy: 0.325000
# lr 3.623898e-07 reg 2.500000e+04 train accuracy: 0.327980 val accuracy: 0.332000
# lr 3.623898e-07 reg 2.871746e+04 train accuracy: 0.320429 val accuracy: 0.331000
# lr 3.623898e-07 reg 3.298770e+04 train accuracy: 0.310816 val accuracy: 0.330000
# lr 3.623898e-07 reg 3.789291e+04 train accuracy: 0.314245 val accuracy: 0.322000
# lr 3.623898e-07 reg 4.352753e+04 train accuracy: 0.315224 val accuracy: 0.333000
# lr 3.623898e-07 reg 5.000000e+04 train accuracy: 0.313510 val accuracy: 0.326000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.330939 val accuracy: 0.344000
# lr 5.000000e-07 reg 2.871746e+04 train accuracy: 0.317878 val accuracy: 0.327000
# lr 5.000000e-07 reg 3.298770e+04 train accuracy: 0.325837 val accuracy: 0.349000
# lr 5.000000e-07 reg 3.789291e+04 train accuracy: 0.301041 val accuracy: 0.310000
# lr 5.000000e-07 reg 4.352753e+04 train accuracy: 0.309755 val accuracy: 0.327000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.303490 val accuracy: 0.316000
# best validation accuracy achieved during cross-validation: 0.349000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.334000

# %% [markdown]
# **Inline Question** - *True or False*
#
# It's possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# *Your answer*:
#
# *Your explanation*:

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
